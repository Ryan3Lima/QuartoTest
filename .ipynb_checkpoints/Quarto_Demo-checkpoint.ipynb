# %% [raw]
# ---
# title: "Quarto Document"
# author: "Ryan E Lima"
# date: "June 7, 2024"
# toc: true
# number-sections: true
# format:
#   html:
#     code-fold: true
#     html-math-method: katex
#     bibliography: references.bib
#   pdf:
#     cite-method: biblatex
#     geometry:
#       - top=30mm
#       - left=30mm
#   docx: default
#
# jupyter: python3
# ---

# %% [markdown]
# ## Example Visualization using Matplotlib

# %%
#| label: fig-plot
#| fig-cap: "Plot"
import numpy as np
a = np.arange(15).reshape(3, 5)
a

import matplotlib.pyplot as plt

fig = plt.figure()
fig.set_size_inches(10,6)
x = np.arange(10)
y = 2.5 * np.sin(x / 20 * np.pi)
yerr = np.linspace(0.05, 0.2, 10)

plt.errorbar(x, y + 3, yerr=yerr, label='both limits (default)')
plt.errorbar(x, y + 2, yerr=yerr, uplims=True, label='uplims=True')
plt.errorbar(x, y + 1, yerr=yerr, uplims=True, lolims=True,
             label='uplims=True, lolims=True')

upperlimits = [True, False] * 5
lowerlimits = [False, True] * 5
plt.errorbar(x, y, yerr=yerr, uplims=upperlimits, lolims=lowerlimits,
             label='subsets of uplims and lolims')

plt.legend(loc='lower right')
plt.show(fig)

# %% [markdown]
# ## Equations using latex
# add 'E = mc^{2}' set inside double $
#
#
# $$E = mc^{2}$$

# %% [markdown]
# ## Example of how references work
#
# blah blah @jones_vulnerability_nodate
#
# blah blah [@jones_vulnerability_nodate]
#
# Other text [see also @tobin_conceptual_2021;@jones_vulnerability_nodate]

# %% [markdown]
# ## Footnotes
#
# Here is a footnote reference, [^1] and another. [^longnote]
#
# [^1]: here is the footnote
# [^longnote]: Here's one with multiple blocks
#
#     Subsequent paragraphs are indented to show that they
# belong to the previous footnote.
#
#         { some.code }
#
#     The whole paragraph can be indented, or just the first
#     line.  In this way, multi-paragraph footnotes work like
#     multi-paragraph list items.
#
# This paragraph won't be part of the note, because it
# isn't indented.

# %% [markdown]
# ## Tables
#
# | Col1 | Col2 | Col3 |
# |------|------|------|
# | A    | B    | C    |
# | E    | F    | G    |
# | A    | G    | G    |
#
# : My Caption {#tbl-letters}
#
# See @tbl-letters

# %% [markdown]
# ## Cross-reference
# [Cross References in Quarto](https://quarto.org/docs/authoring/cross-references.html)
#
# For example, see @fig-plot.
# See @tbl-letters
